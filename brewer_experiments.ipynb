# %% [markdown]
# # BrewER Experiments
# Este notebook replica as funcionalidades do experiments.ipynb para o algoritmo BrewER

# %%
import pandas as pd
import pickle as pkl
from collections import deque
import time
import itertools as it
import numpy as np
import math
import pprint

import re

from brewer import Task, brewer, blocking, matching, fusion, parser

import variables as var

from itertools import combinations

# %%
# Change to raw dataset path
data = pd.read_csv("datasets/alaska_cameras_small/dataset.csv")

# Change to matches (dataframe with l_id and r_id pairs)
matches = pd.read_csv("datasets/alaska_cameras_small/matches.csv")

# Change to a pickled candidate pairs file (list of pairs)
with open(
    "datasets/alaska_cameras_small/blocking_functions/candidates_sparker.pkl",
    "rb",
) as f:
    candidates = pkl.load(f)

# %%
# If your matches aren't using l_id and r_id, or you have a different matching function change here
def matcher(l, r):
    return (
        ((matches["l_id"] == l) & (matches["r_id"] == r))
        | ((matches["l_id"] == r) & (matches["r_id"] == l))
    ).any()

# %%
# Change based on the aggregation functions you want to use for BrewER
def resolve_batch(records):
    entity = {}
    entity["_id"] = records['_id'].mode()[0]
    entity["description"] = records['description'].mode()[0]
    entity["brand"] = records['brand'].mode()[0]
    entity["price"] = records["price"].min()
    entity["mp"] = records["mp"].mean()
    return entity

# %%
def match_batch(candidate_pairs):
    seen = set()
    matches_set = set()
    not_matches_set = set()
    result = []
    comparisons = 0
    for idx, row in data.iterrows():
        # Change if your id column is different
        root = row["_id"]
        if root in seen:
            continue

        pairs = [pair for pair in candidate_pairs if root in pair]
        if not pairs:
            continue

        block = set().union(*pairs)

        entity_cluster = set([root])
        to_analyze = deque([root])

        while to_analyze:
            id = to_analyze.popleft()
            for candidate in block:
                if candidate in entity_cluster:
                    continue
                if id == candidate:
                    entity_cluster.add(candidate)
                    continue
                if (id, candidate) in matches_set:
                    entity_cluster.add(candidate)
                    to_analyze.append(candidate)
                    continue
                if (id, candidate) in not_matches_set:
                    continue
                comparisons += 1
                if matcher(id, candidate):
                    entity_cluster.add(candidate)
                    matches_set.add((id, candidate))
                    matches_set.add((candidate, id))
                    to_analyze.append(candidate)
                else:
                    not_matches_set.add((id, candidate))
                    not_matches_set.add((candidate, id))

        seen.update(entity_cluster)
        result.append(entity_cluster)
    return result, comparisons

# %%
# Run batch processing for comparison
start = time.time()

results, batch_comparisons = match_batch(candidates)

batch_elapsed_time = time.time() - start

# %%
# Change if your id column is different
resolved = pd.DataFrame([resolve_batch(data[data["_id"].isin(entity)]) for entity in results])
# Change to the where query you used on BrewER, and the order by
batch_filtered = resolved[resolved["brand"] == "sony"].sort_values(
    "mp", ascending=False
)
batch_filtered_pairs = set()
for group in (results[index] for index in batch_filtered.index):
    if len(group) > 1:
        batch_filtered_pairs.update([tuple(sorted(pair)) for pair in combinations(group, 2)])
    else:
        batch_filtered_pairs.add(tuple(group))

# %%
print("Batch filtered pairs:")
batch_filtered_pairs
# Out:
# Batch filtered pairs:
# {('www.ebay.com//53965', 'www.walmart.com//800'),
#  ('www.ebay.com//23894', 'www.ebay.com//55524'),
#  ('www.ebay.com//44472', 'www.ebay.com//52649'),
#  ('www.ebay.com//48530', 'www.ebay.com//54868'),
#  ('www.ebay.com//52699', 'www.gosale.com//395'),
#  ('www.ebay.com//58055', 'www.gosale.com//1003'),
#  ('www.ebay.com//55319', 'www.ebay.com//56820'),
#  ('www.ebay.com//48416', 'www.ebay.com//52850'),
#  ('www.ebay.com//53459', 'www.gosale.com//910'),
#  ('www.ebay.com//56954', 'www.ebay.com//59551'),
#  ('www.ebay.com//53854', 'www.ebay.com//58055'),
#  ('www.ebay.com//58197', 'www.gosale.com//1411'),
#  ('buy.net//5752', 'www.gosale.com//821'),
#  ('www.ebay.com//55330', 'www.henrys.com//113'),
#  ('buy.net//5596', 'www.gosale.com//759'),
#  ('www.ebay.com//42996', 'www.ebay.com//55524'),
#  ('www.ebay.com//24233', 'www.ebay.com//42356'),
#  ('www.ebay.com//54406', 'www.gosale.com//751'),
#  ('www.ebay.com//44373', 'www.ebay.com//54490'),
#  ('www.buzzillions.com//956', 'www.ebay.com//60386'),
#  ('www.ebay.com//43767', 'www.ebay.com//53050'),
#  ('www.ebay.com//24382', 'www.ebay.com//44137'),
#  ('www.ebay.com//48548', 'www.ebay.com//53209'),
#  ('www.ebay.com//46684', 'www.ebay.com//46718'),
#  ('www.ebay.com//42032', 'www.ebay.com//43090'),
#  ('www.ebay.com//60670', 'www.gosale.com//857'),
#  ('www.ebay.com//43287', 'www.ebay.com//54873'),
#  ('www.ebay.com//45873', 'www.ebay.com//46475'),
#  ('www.ebay.com//42559', 'www.ebay.com//59883'),
#  ('www.ebay.com//54349', 'www.ebay.com//54548'),
#  ('www.ebay.com//44326', 'www.gosale.com//1411'),
#  ('www.ebay.com//60386', 'www.gosale.com//738'),
#  ('www.ebay.com//47187', 'www.ebay.com//56737'),
#  ('www.ebay.com//43106',),
#  ('www.ebay.com//42416', 'www.ebay.com//59882'),
#  ('www.ebay.com//47280', 'www.ebay.com//52701'),
#  ('www.ebay.com//45709', 'www.ebay.com//54548'),
#  ('www.ebay.com//24262', 'www.ebay.com//47358'),
#  ('www.ebay.com//42093', 'www.ebay.com//44046'),
#  ('www.ebay.com//52850', 'www.gosale.com//827'),
#  ('www.ebay.com//47280', 'www.walmart.com//700'),
#  ('www.ebay.com//47391', 'www.ebay.com//53866'),
#  ('www.ebay.com//43262',),
#  ('buy.net//5549', 'www.ebay.com//46243'),
#  ('www.ebay.com//47188', 'www.ebay.com//58578'),
#  ('www.ebay.com//42089', 'www.ebay.com//45040'),
#  ('www.ebay.com//53608', 'www.ebay.com//53854'),
#  ...}

# %%
print("Batch comparisons:", batch_comparisons)
print("Batch elapsed time:", batch_elapsed_time)
print("Batch emitted:", len(batch_filtered))
# Out:
# Batch comparisons: 22073
# Batch elapsed time: 59.14668393135071
# Batch emitted: 206

# %%
# Prepare gold standard for BrewER matching function
gold = set()
for _, match in matches.iterrows():
    gold.add((match["l_id"], match["r_id"]))
    gold.add((match["r_id"], match["l_id"]))

# %%
# Initialize BrewER results tracking
brewer_start = None
brewer_results = []
brewer_entities = []

def track_brewer_results(entity):
    global brewer_start, brewer_results, brewer_entities

    brewer_entities.append(entity)
    i = len(brewer_entities) - 1

    cluster = entity.get("matches", [entity["_id"]]) 
    if isinstance(cluster, (set, list)) and len(cluster) > 1:
        cluster_pairs = set(tuple(sorted(p)) for p in combinations(cluster, 2))
    else:
        cluster_pairs = set()

    tp = len(cluster_pairs & batch_filtered_pairs)
    fp = len(cluster_pairs - batch_filtered_pairs)

    correct = (round(entity["mp"], 3) == round(batch_filtered.iloc[i]['mp'], 3)) if i < len(batch_filtered) else False


    brewer_results.append({
        "elapsed_time": entity.get("time", time.time() - brewer_start),
        "comparisons": entity.get("comparisons", 0),
        "correct": correct,
        "tp": tp,
        "fp": fp,
    })

# %%
# Configure BrewER task
# Create a SQL query for BrewER - must follow the exact syntax expected by the parser
# This replicates the same query from the BlendER experiments.ipynb:
# - SELECT: VOTE(_id), VOTE(description), VOTE(brand), MIN(price), AVG(mp)
# - WHERE: brand = "sony" 
# - ORDER BY: mp DESC
sql_query = '''
SELECT VOTE(_id), VOTE(description), VOTE(brand), MIN(price), AVG(mp)
FROM alaska_cameras_small
GROUP BY ENTITY WITH MATCHER bf_sparker_mf_gt
HAVING VOTE(brand) = "sony"
ORDER BY AVG(mp) DESC
'''

print("Configuring BrewER task...")

# Create task object
class SimpleSQL:
    def __init__(self, value):
        self.value = value

sql_obj = SimpleSQL(sql_query)
parsed_query = parser(sql_obj)

if parsed_query["complete"]:
    task = Task(parsed_query)
    print("Task created successfully!")
    print(f"Dataset: {task.ds}")
    print(f"Blocking function: {task.blocking_function}")
    print(f"Matching function: {task.matching_function}")
    print(f"Ordering key: {task.ordering_key}")
    print(f"Ordering mode: {task.ordering_mode}")
    print(f"Aggregation functions: {task.aggregation_functions}")
else:
    print("Error: SQL query parsing failed!")
    print("Parsed query:", parsed_query)
# Out:
# Configuring BrewER task...
# Task created successfully!
# Dataset: alaska_cameras_small
# Blocking function: SparkER (Meta-Blocking)
# Matching function: Ground Truth
# Ordering key: mp
# Ordering mode: desc
# Aggregation functions: {'_id': 'vote', 'description': 'vote', 'brand': 'vote', 'price': 'min', 'mp': 'avg'}

# %%
# Run BrewER algorithm (reutilizando a função matcher do batch)
if 'task' in locals() and parsed_query["complete"]:
    brewer_start = time.time()
    brewer_results = []
    brewer_entities = []

    # gold fica sem uso aqui; a função matcher do batch será chamada diretamente
    gold = []  # apenas placeholder

    # Candidates
    candidates_set = set(candidates)

    try:
        import importlib, brewer as brewer_mod
        importlib.reload(brewer_mod)

        # matching do Brewer delega para o seu matcher do batch
        def _my_matching(left_id, right_id, _gold_ignored):
            return matcher(left_id, right_id)  # usa a MESMA lógica do batch
        brewer_mod.matching = _my_matching

        results_df = brewer_mod.brewer(
            task, data, gold, candidates_set,
            demo=False, mode="scratch", results=[]
        )

        print(f"BrewER completed successfully! Emitted {len(results_df)} entities.")

        for _, entity in results_df.iterrows():
            track_brewer_results(entity.to_dict())

    except Exception as e:
        print(f"Error running BrewER: {e}")
        results_df = pd.DataFrame()

else:
    print("Cannot run BrewER: task creation failed or query parsing failed.")
    results_df = pd.DataFrame()
# Out:
# BrewER is running: setup started.
#
# Setup completed... let's go!
#
# {'_id': 0,
#  'brand': 'sony',
#  'comparisons': 2,
#  'description': 'sony a7r black interchangeable lens digital slr camera body '
#                 'only (36.4 mp, memory stick/sd card slot) price comparison at '
#                 'buy.net',
#  'matches': ['www.gosale.com//1215', 'buy.net//5881'],
#  'mp': np.float64(36.4),
#  'price': np.float64(1586.99),
#  'time': 1.2859959602355957}
# {'_id': 1,
#  'brand': 'sony',
#  'comparisons': 2,
#  'description': 'sony alpha a7r 36 4 mp full frame mirrorless camera body open '
#                 'box $1 027242874787 | ebay',
#  'matches': ['www.ebay.com//53668'],
#  'mp': np.float64(36.4),
#  'price': np.float64(nan),
#  'time': 1.2897229194641113}
# {'_id': 2,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha ilce 6000l 24 3mp slr digital camera with e pz 16 '
#                 '50mm lens black | ebay',
#  'matches': ['www.ebay.com//46949'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.392333745956421}
# {'_id': 3,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera w 18 55mm lens '
#                 'boxed sn0757616 | ebay',
#  'matches': ['www.ebay.com//59882',
#              'www.gosale.com//531',
#              'www.ebay.com//42034',
#              'www.ebay.com//45125',
#              'www.gosale.com//521'],
#  'mp': np.float64(24.3),
#  'price': np.float64(827.99),
#  'time': 2.395238161087036}
# {'_id': 4,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha nex 7 24 3 mp digital camera sel 18 55mm '
#                 'lens kit black mint | ebay',
#  'matches': ['www.ebay.com//42367'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.3978867530822754}
# {'_id': 5,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha nex 7 24 3mp digital camera with 18 55mm lens '
#                 'black | ebay',
#  'matches': ['www.ebay.com//42416'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4005582332611084}
# {'_id': 6,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony nex 7 digital camera 24 3 mp w 50 mm 1 8f portrait lens '
#                 'sd card and case | ebay',
#  'matches': ['www.ebay.com//44911'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4032461643218994}
# {'_id': 7,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera black body only | '
#                 'ebay',
#  'matches': ['www.ebay.com//48530'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4060680866241455}
# {'_id': 8,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony nex 7 24 3 mp digital camera black kit w 18 55mm lens '
#                 'from japan | ebay',
#  'matches': ['www.ebay.com//53798'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4087040424346924}
# {'_id': 9,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha nex 7 digital slr camera w 18 55mm lens 24 3mp '
#                 'mirrorless mint nex7 | ebay',
#  'matches': ['www.ebay.com//54864'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.411480188369751}
# {'_id': 10,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera black body only | '
#                 'ebay',
#  'matches': ['www.ebay.com//54868'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.414473056793213}
# {'_id': 11,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera black body only | '
#                 'ebay',
#  'matches': ['www.ebay.com//56902'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.417558431625366}
# {'_id': 12,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera black kit w 18 55mm '
#                 'lens | ebay',
#  'matches': ['www.ebay.com//57058'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4202382564544678}
# {'_id': 13,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha nex 7 24 3 mp digital camera black body only with '
#                 'some extras | ebay',
#  'matches': ['www.ebay.com//58641'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.423658847808838}
# {'_id': 14,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera black kit w 18 55mm '
#                 'lens | ebay',
#  'matches': ['www.ebay.com//58982'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4261903762817383}
# {'_id': 15,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony nex 7 24 3 mp digital camera body look | ebay',
#  'matches': ['www.ebay.com//59299'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4297289848327637}
# {'_id': 16,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony nex 7 24 3 mp ultra compact interchangeable lens digital '
#                 'camera 23875 | ebay',
#  'matches': ['www.ebay.com//59607'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.432267189025879}
# {'_id': 17,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera black body only | '
#                 'ebay',
#  'matches': ['www.ebay.com//59950'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.435983419418335}
# {'_id': 18,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha nex 7 24 3 mp digital camera 20mm lens and canon '
#                 'adapter | ebay',
#  'matches': ['www.ebay.com//60260'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4390439987182617}
# {'_id': 19,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha nex 7 24 3 mp digital camera black with sony 35mm '
#                 'and 18 105mm | ebay',
#  'matches': ['www.ebay.com//60426'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4423043727874756}
# {'_id': 20,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony nex 7 digital camera 24 3mp 18 55mm lens kit full hd '
#                 'video black new | ebay',
#  'matches': ['www.ebay.com//60659'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.445185899734497}
# {'_id': 21,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha î\x91 nex 7 24 3mp aps c compact mirrorless outfit '
#                 'w 18 55mm bx mint | ebay',
#  'matches': ['www.ebay.com//60750'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4483015537261963}
# {'_id': 22,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha slta77vm black slr digital camera kit w/ 18*135mm '
#                 'lens (24.3 mp, 7.5x opt, memory stick pro duo/pro-hg '
#                 'duo/pro-hg hx duo/sd/sdhc/sdxc card slot) price comparison at '
#                 'buy.net',
#  'matches': ['buy.net//4330'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.451389789581299}
# {'_id': 23,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'cammarkt | sony a77vm 24.3 mp translucent mirror digital slr '
#                 'with 18-135mm',
#  'matches': ['cammarkt.com//229'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.454951286315918}
# {'_id': 24,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7k full-frame 24.3 mp digital on sale for $1468.00',
#  'matches': ['www.gosale.com//540'],
#  'mp': np.float64(24.3),
#  'price': np.float64(1379.99),
#  'time': 2.45782732963562}
# {'_id': 25,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7 ilce 7 24 3 mp extra charger mint condition | ebay',
#  'matches': ['buy.net//6531', 'www.gosale.com//498', 'www.ebay.com//54604'],
#  'mp': np.float64(24.3),
#  'price': np.float64(1172.99),
#  'time': 2.461312770843506}
# {'_id': 26,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7 ilce 7 24 3 mp digital ff camera body only with box '
#                 'and accessories | ebay',
#  'matches': ['www.ebay.com//42961'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4656929969787598}
# {'_id': 27,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a7 24 3 mp mirrorless digital camera with 28 70mm '
#                 'lens kit 0027242874800 | ebay',
#  'matches': ['www.ebay.com//43248'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4697868824005127}
# {'_id': 28,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7 full frame 24 3 mp camera kit 28 70mm lens warranty '
#                 '0027242874800 | ebay',
#  'matches': ['www.ebay.com//43366'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.473865032196045}
# {'_id': 29,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7 full frame 24 3 mp interchangeable digital camera '
#                 'body only warranty | ebay',
#  'matches': ['www.ebay.com//44087'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4787378311157227}
# {'_id': 30,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a7 24 3mp full frame digital camera body only '
#                 's4242 | ebay',
#  'matches': ['www.ebay.com//53323'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.483289957046509}
# {'_id': 31,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7 alpha ilce 7 24 3 mp digital slr camera black body '
#                 'only | ebay',
#  'matches': ['www.ebay.com//54541'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.486738681793213}
# {'_id': 32,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a7 alpha mirrorless digital camera body only 24 3mp full '
#                 'frame warranty rx | ebay',
#  'matches': ['www.ebay.com//60234'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4909791946411133}
# {'_id': 33,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a7 ilce-7/b digital slr camera with 24.3 '
#                 'megapixels - walmart.com',
#  'matches': ['www.walmart.com//767'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.494729518890381}
# {'_id': 34,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony cybershot dsc rx1r 24 3 mp digital camera evf fdaev1mk '
#                 'hood grip | ebay',
#  'matches': ['www.ebay.com//25140'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.4980785846710205}
# {'_id': 35,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony cyber shot dsc rx1r 24 3 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//43858'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5015618801116943}
# {'_id': 36,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony dsc rx1r 24 3mp full frame digital camera with leather '
#                 'case | ebay',
#  'matches': ['www.ebay.com//60163'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.505143404006958}
# {'_id': 37,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'buy sony cyber-shot rx1r digital camera, 24.3mp, black '
#                 'cameras - digital - point & shoot dscrx1r/b today at pc '
#                 'connection',
#  'matches': ['www.pcconnection.com//12397'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.510019540786743}
# {'_id': 38,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'new sony alpha a6000 24 3mp digital black e mount camera body '
#                 '16 50mm pz lens | ebay',
#  'matches': ['www.gosale.com//806',
#              'buy.net//6417',
#              'www.gosale.com//395',
#              'www.ebay.com//48365',
#              'www.gosale.com//450',
#              'buy.net//6117'],
#  'mp': np.float64(24.3),
#  'price': np.float64(448.49),
#  'time': 2.514064311981201}
# {'_id': 39,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 black digital camera kit w/ 16-50 mm lens '
#                 '(24.3 mp, 3x opt, sd/sdhc/sdxc/ms pro duo/ms pro-hg duo card '
#                 'slot) price comparison at buy.net',
#  'matches': ['buy.net//6447'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.516890525817871}
# {'_id': 40,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 body black 16 50mm oss zoom lens pal version '
#                 '24 3mp | ebay',
#  'matches': ['www.ebay.com//42966'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.519559383392334}
# {'_id': 41,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha a6000 24 3 mp digital camera black body only '
#                 'ilce 6000 | ebay',
#  'matches': ['www.ebay.com//44556'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5230658054351807}
# {'_id': 42,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 hd wi fi digital camera 24 3mp 16 50mm lens '
#                 'black kit | ebay',
#  'matches': ['www.ebay.com//44620'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.52644944190979}
# {'_id': 43,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 24 3 mp interchangeable camera with 16 50mm '
#                 'power zoom lens | ebay',
#  'matches': ['www.ebay.com//44951'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5293502807617188}
# {'_id': 44,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha a6000 24 3 mp silver body only latest model '
#                 'and extras | ebay',
#  'matches': ['www.ebay.com//47392'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5327882766723633}
# {'_id': 45,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 hd wi fi digital camera 24 3mp 16 50mm lens '
#                 'black kit | ebay',
#  'matches': ['www.ebay.com//53547'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5361948013305664}
# {'_id': 46,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha a6000 24 3 mp black kit w 16 50mm lens '
#                 'latest model mint | ebay',
#  'matches': ['www.ebay.com//55122'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5397000312805176}
# {'_id': 47,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 hd wi fi digital camera body silver 24 3mp '
#                 'new usa | ebay',
#  'matches': ['www.ebay.com//55720'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5425825119018555}
# {'_id': 48,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha a6000 24 3 mp digital camera black body only '
#                 'latest model | ebay',
#  'matches': ['www.ebay.com//60783'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.545597553253174}
# {'_id': 49,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a77 24.3 mp digital slr on sale for $917.19',
#  'matches': ['www.gosale.com//1251',
#              'www.ebay.com//42742',
#              'www.ebay.com//43901'],
#  'mp': np.float64(24.3),
#  'price': np.float64(1655.97),
#  'time': 2.54933762550354}
# {'_id': 50,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77 24 3 mp digital slr camera black '
#                 'body only 027242833067 | ebay',
#  'matches': ['www.ebay.com//44753'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5521962642669678}
# {'_id': 51,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a77 24 3 mp digital slr camera with translucent mirror '
#                 'technology 23562 027242833067 | ebay',
#  'matches': ['www.ebay.com//46562'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5567688941955566}
# {'_id': 52,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77 24 3 mp digital slr camera excellent '
#                 'from japan f s 027242833067 | ebay',
#  'matches': ['www.ebay.com//48548'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5606820583343506}
# {'_id': 53,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony a alpha slt a77 24 3 mp digital slr camera black with '
#                 'nice lens 027242833074 | ebay',
#  'matches': ['www.ebay.com//53209'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5643842220306396}
# {'_id': 54,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77 24 3 mp digital slr camera w 3 lens '
#                 'sigma flash more 027242833067 | ebay',
#  'matches': ['www.ebay.com//53807'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5673038959503174}
# {'_id': 55,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77 24 3 mp digital slr camera black '
#                 'body only 027242833067 | ebay',
#  'matches': ['www.ebay.com//54163'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5702028274536133}
# {'_id': 56,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha slt a77 24 3 mp digital slr camera body only a 77 '
#                 '241065 027242833067 | ebay',
#  'matches': ['www.ebay.com//56883'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5729501247406006}
# {'_id': 57,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77 24 3 mp digital slr camera black '
#                 'body only 027242833067 | ebay',
#  'matches': ['www.ebay.com//57755'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.575772285461426}
# {'_id': 58,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77 24 3 mp digital slr camera w 3 lens '
#                 'sigma flash more 027242833067 | ebay',
#  'matches': ['www.ebay.com//57927'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5783915519714355}
# {'_id': 59,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77v 24 3 mp digital slr camera with '
#                 'vertical grip | ebay',
#  'matches': ['www.ebay.com//43490'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.581129550933838}
# {'_id': 60,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77v 24 3 mp digital slr camera with '
#                 'vertical grip | ebay',
#  'matches': ['www.ebay.com//46677'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5837819576263428}
# {'_id': 61,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77v 24 3 mp digital slr camera with '
#                 'vertical grip | ebay',
#  'matches': ['www.ebay.com//54853'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.586590051651001}
# {'_id': 62,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony î\x91 alpha slt a77v 24 3 mp digital slr camera with '
#                 'vertical grip | ebay',
#  'matches': ['www.ebay.com//56640'],
#  'mp': np.float64(24.3),
#  'price': np.float64(nan),
#  'time': 2.5893361568450928}
# {'_id': 63,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony cyber-shot dsc-rx1r 24mp compact on sale for $2158.65',
#  'matches': ['www.gosale.com//1395', 'buy.net//5408'],
#  'mp': np.float64(24.15),
#  'price': np.float64(1931.99),
#  'time': 2.5931246280670166}
# {'_id': 64,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony dsc-rx1r 24mp fullframe w/0 lp fltr dscrx1r',
#  'matches': ['www.henrys.com//26'],
#  'mp': np.float64(24.0),
#  'price': np.float64(nan),
#  'time': 2.5976803302764893}
# {'_id': 65,
#  'brand': 'sony',
#  'comparisons': 412,
#  'description': 'sony alpha a6000 24mp mirror less digital camera with kit 16 '
#                 '50 lens | ebay',
#  'matches': ['www.ebay.com//52699'],
#  'mp': np.float64(24.0),
#  'price': np.float64(nan),
#  'time': 2.6012327671051025}
# {'_id': 66,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony dschx400vb black 20.4mp 50x wide angle 3" dschx400vb',
#  'matches': ['www.henrys.com//187'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.269060134887695}
# {'_id': 67,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx400 20 4 mp digital camera black super '
#                 'offers | ebay',
#  'matches': ['www.ebay.com//42447'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.272778272628784}
# {'_id': 68,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony dsc-hx300b black 20.4mp 50x 3" cmos dschx300b',
#  'matches': ['www.henrys.com//156'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.275853157043457}
# {'_id': 69,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black brand '
#                 'new unopened | ebay',
#  'matches': ['www.ebay.com//24156'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.27864933013916}
# {'_id': 70,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//42515'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.281961679458618}
# {'_id': 71,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black used '
#                 'with extras | ebay',
#  'matches': ['www.ebay.com//46046'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.28557014465332}
# {'_id': 72,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black '
#                 'batteries and charger | ebay',
#  'matches': ['www.ebay.com//46243'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.288031101226807}
# {'_id': 73,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera new in box '
#                 'free shipping | ebay',
#  'matches': ['www.ebay.com//53525'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.290541410446167}
# {'_id': 74,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black kiwi '
#                 'lens hood kit | ebay',
#  'matches': ['www.ebay.com//55278'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.2931435108184814}
# {'_id': 75,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'new sony cyber shot dsc hx300 black camera 20 4mp body only '
#                 'nothing else | ebay',
#  'matches': ['www.ebay.com//55941'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.295733451843262}
# {'_id': 76,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//56414'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.298303127288818}
# {'_id': 77,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx300 20 4 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//59847'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.301519393920898}
# {'_id': 78,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx50v 20 4 mp digital camera black | ebay',
#  'matches': ['www.gosale.com//1158',
#              'www.buzzillions.com//2484',
#              'www.ebay.com//53466'],
#  'mp': np.float64(20.4),
#  'price': np.float64(310.49),
#  'time': 5.304365158081055}
# {'_id': 79,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx50v 20 4 mp digital camera silver | '
#                 'ebay',
#  'matches': ['www.ebay.com//42356'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.3074939250946045}
# {'_id': 80,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot dsc hx50v 20 4 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//46633'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.310266733169556}
# {'_id': 81,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot hx50v 20 4 mp digital camera black '
#                 '027242862227 | ebay',
#  'matches': ['www.ebay.com//56480'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.312711000442505}
# {'_id': 82,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'sony cyber shot hx50v 20 4 mp digital camera black '
#                 '027242862227 | ebay',
#  'matches': ['www.ebay.com//60259'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.315460920333862}
# {'_id': 83,
#  'brand': 'sony',
#  'comparisons': 1441,
#  'description': 'buy sony cyber-shot digital camera hx50v, 20.4mp, black '
#                 'cameras - digital - point & shoot dschx50v/b today at pc '
#                 'connection',
#  'matches': ['www.pcconnection.com//12182'],
#  'mp': np.float64(20.4),
#  'price': np.float64(nan),
#  'time': 5.317947864532471}
# {'_id': 84,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber-shot dsc-hx400 black digital camera (20.4 mp, 50x '
#                 'opt, sd/sdhc/ms pro duo/ms pro hg-duo card slot) price '
#                 'comparison at buy.net',
#  'matches': ['www.gosale.com//950', 'buy.net//6666'],
#  'mp': np.float64(20.2),
#  'price': np.float64(344.99),
#  'time': 8.441067934036255}
# {'_id': 85,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber-shot dsc-hx300 black digital camera (20.4 mp, 50x '
#                 'opt, ms/sd card slot) price comparison at buy.net',
#  'matches': ['buy.net//5549', 'www.gosale.com//483'],
#  'mp': np.float64(20.2),
#  'price': np.float64(344.99),
#  'time': 8.444211959838867}
# {'_id': 86,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber-shot dsc-rx100 black digital camera (20.2 mp, 3.6x '
#                 'opt, sd/sdhc/sdxc/ms duo/ms pro duo/ms pro-hg duo card slot) '
#                 'price comparison at buy.net',
#  'matches': ['www.gosale.com//759', 'buy.net//5596', 'buy.net//5909'],
#  'mp': np.float64(20.2),
#  'price': np.float64(447.12),
#  'time': 8.447752475738525}
# {'_id': 87,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony dsc-rx100/b black digital camera (20.2 mp, 3.6x opt, '
#                 'sd/sdxc/sdhc/ms duo card slot) price comparison at buy.net',
#  'matches': ['buy.net//6383'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.450539827346802}
# {'_id': 88,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//24547'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.453648567199707}
# {'_id': 89,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//41969'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.456387758255005}
# {'_id': 90,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber-shot dsc-rx100 20.2 mp digital camera - black',
#  'matches': ['www.ebay.com//42093'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.459444522857666}
# {'_id': 91,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii m2 20 2 mp digital camera black '
#                 'lightly used 027242870802 | ebay',
#  'matches': ['www.ebay.com//42426'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.462161302566528}
# {'_id': 92,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera rx 100 one '
#                 'owner | ebay',
#  'matches': ['www.ebay.com//42559'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.46517562866211}
# {'_id': 93,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii 20 2 mp digital camera black '
#                 '027242870802 | ebay',
#  'matches': ['www.ebay.com//43262'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.468156337738037}
# {'_id': 94,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black '
#                 'warranty | ebay',
#  'matches': ['www.ebay.com//43287'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.471091985702515}
# {'_id': 95,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera excellent '
#                 'reduced $$ | ebay',
#  'matches': ['www.ebay.com//43942'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.474676847457886}
# {'_id': 96,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//44046'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.477781057357788}
# {'_id': 97,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//44209'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.480400085449219}
# {'_id': 98,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black rx100 '
#                 '| ebay',
#  'matches': ['www.ebay.com//44857'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.483294486999512}
# {'_id': 99,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii 20 2 mp digital camera black '
#                 '027242870802 | ebay',
#  'matches': ['www.ebay.com//45269'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.486202239990234}
# {'_id': 100,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//45372'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.490018606185913}
# {'_id': 101,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber-shot dsc-rx100 20.2 mp digital camera from japan',
#  'matches': ['www.ebay.com//45873'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.492828845977783}
# {'_id': 102,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cybershot dsc rx100 20 2 mp digital camera cyber shot '
#                 'black great condition | ebay',
#  'matches': ['www.ebay.com//46062'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.49656057357788}
# {'_id': 103,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp grip and camera leathers | '
#                 'ebay',
#  'matches': ['www.ebay.com//46475'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.499324560165405}
# {'_id': 104,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'used sony cyber shot dsc rx100 ii 20 2 mp digital camera '
#                 'black 027242870802 | ebay',
#  'matches': ['www.ebay.com//46570'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.504223108291626}
# {'_id': 105,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'used sony cyber shot dsc rx100 ii 20 2 mp digital camera '
#                 'black 027242870802 | ebay',
#  'matches': ['www.ebay.com//46695'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.508754253387451}
# {'_id': 106,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony dsc rx100 cyber shot digital camera 20 2mp case used $1 '
#                 '| ebay',
#  'matches': ['www.ebay.com//46936'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.512358665466309}
# {'_id': 107,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black w lots '
#                 'of extras | ebay',
#  'matches': ['www.ebay.com//47096'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.51592755317688}
# {'_id': 108,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//47297'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.518946409225464}
# {'_id': 109,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii 20 2 mp digital camera black '
#                 '027242870802 | ebay',
#  'matches': ['www.ebay.com//52648'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.522220611572266}
# {'_id': 110,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'used sony cyber shot dsc rx100 ii 20 2 mp digital camera '
#                 'black 027242870802 | ebay',
#  'matches': ['www.ebay.com//52688'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.525583982467651}
# {'_id': 111,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//52701'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.5287024974823}
# {'_id': 112,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'used sony cyber shot dsc rx100 ii 20 2 mp digital camera '
#                 'black 027242870802 | ebay',
#  'matches': ['www.ebay.com//52890'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.532171964645386}
# {'_id': 113,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp w grip 2 memory cards | '
#                 'ebay',
#  'matches': ['www.ebay.com//53441'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.535492420196533}
# {'_id': 114,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii 20 2 mp digital camera black '
#                 '027242870802 | ebay',
#  'matches': ['www.ebay.com//53732'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.53871750831604}
# {'_id': 115,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//54036'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.541454553604126}
# {'_id': 116,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii 20 2 mp digital camera black '
#                 '027242870802 | ebay',
#  'matches': ['www.ebay.com//54281'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.544319868087769}
# {'_id': 117,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 ii m2 20 2 mp digital camera free '
#                 'extras 027242870802 | ebay',
#  'matches': ['www.ebay.com//54778'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.547021389007568}
# {'_id': 118,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//54873'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.54960823059082}
# {'_id': 119,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'used sony cyber shot dsc rx100 ii 20 2 mp digital camera '
#                 'black 027242870802 | ebay',
#  'matches': ['www.ebay.com//54940'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.552123785018921}
# {'_id': 120,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//55392'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.554633617401123}
# {'_id': 121,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//56199'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.557323694229126}
# {'_id': 122,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100 20 2 mp digital camera extras | '
#                 'ebay',
#  'matches': ['www.ebay.com//59883'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.560219764709473}
# {'_id': 123,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony dsc-rx100 20.2mp cmos 3.6x 3" dscrx100',
#  'matches': ['www.henrys.com//43'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.565126895904541}
# {'_id': 124,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'buy sony cyber-shot digital camera rx100 ii, 20.2mp, black '
#                 'cameras - digital - point & shoot dscrx100m2/b today at pc '
#                 'connection',
#  'matches': ['www.pcconnection.com//12443'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.569570064544678}
# {'_id': 125,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'purchase the sony cybershot rx100, 20.2mp for less at '
#                 'walmart.com. save money. live better.',
#  'matches': ['www.walmart.com//700'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.572355508804321}
# {'_id': 126,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'new sony professional compact digital 20 2mp camera dscrx100 '
#                 'b | ebay',
#  'matches': ['www.ebay.com//55054'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.575384855270386}
# {'_id': 127,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber-shot dsc-rx100m ii 20.2mp on sale for $474.99',
#  'matches': ['buy.net//6400', 'www.gosale.com//1458', 'www.ebay.com//24338'],
#  'mp': np.float64(20.2),
#  'price': np.float64(517.49),
#  'time': 8.578745365142822}
# {'_id': 128,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx100m2 20 2 mp digital camera black '
#                 '027242870802 | ebay',
#  'matches': ['www.ebay.com//48219'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.582316637039185}
# {'_id': 129,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony dsc-rx100m2 20.2mp 3.6x 3"  1"cmos dscrx100m2',
#  'matches': ['www.henrys.com//207'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.585450172424316}
# {'_id': 130,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx10 20 2 mp digital camera mint '
#                 'condition perfect seller 027242870796 | ebay',
#  'matches': ['buy.net//6674', 'www.gosale.com//1166', 'www.ebay.com//42048'],
#  'mp': np.float64(20.2),
#  'price': np.float64(896.99),
#  'time': 8.58850646018982}
# {'_id': 131,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony cyber shot dsc rx10 20 2 mp digital camera black mint '
#                 'with many extras | ebay',
#  'matches': ['www.ebay.com//43541'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.591859340667725}
# {'_id': 132,
#  'brand': 'sony',
#  'comparisons': 2608,
#  'description': 'sony dsc-rx10 20.2mp 24-200mm f2.8 3"lcd dscrx10',
#  'matches': ['www.henrys.com//140'],
#  'mp': np.float64(20.2),
#  'price': np.float64(nan),
#  'time': 8.594939231872559}
# {'_id': 133,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc rx100 iii wi fi hd digital camera kit 20 '
#                 '1mp black new usa | ebay',
#  'matches': ['www.ebay.com//43533'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.547963857650757}
# {'_id': 134,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'top sony cyber shot rx100 iii 20 1 mp digital camera black '
#                 'carl zeiss rx100m3 | ebay',
#  'matches': ['www.ebay.com//48359'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.550574779510498}
# {'_id': 135,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'new sony cyber shot rx100 iii 20 1 mp digital camera black '
#                 'carl zeiss rx100m3 | ebay',
#  'matches': ['www.ebay.com//48490'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.553008317947388}
# {'_id': 136,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony rx100 iii m3 20 1mp compact digital camera | ebay',
#  'matches': ['www.ebay.com//52902'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.55631947517395}
# {'_id': 137,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony dsc rx100 cyber shot digital camera 20 1mp black 32gb '
#                 'flash card battery | ebay',
#  'matches': ['www.ebay.com//53679'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.558793544769287}
# {'_id': 138,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot rx100 iii dsc rx100m3 b black 20 1mp 2 9x '
#                 'optical zoom digital c | ebay',
#  'matches': ['www.ebay.com//59012'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.561667203903198}
# {'_id': 139,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc rx100 iii wi fi hd digital camera kit 20 '
#                 '1mp black new usa | ebay',
#  'matches': ['www.ebay.com//59317'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.564355611801147}
# {'_id': 140,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cybershot dsc-rx100m iii 20.1mp on sale for $798.00',
#  'matches': ['www.gosale.com//557'],
#  'mp': np.float64(20.1),
#  'price': np.float64(550.62),
#  'time': 9.567092895507812}
# {'_id': 141,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//55235',
#              'www.ebay.com//24262',
#              'www.gosale.com//1190'],
#  'mp': np.float64(20.1),
#  'price': np.float64(172.49),
#  'time': 9.570467948913574}
# {'_id': 142,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//42799'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.573466539382935}
# {'_id': 143,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//47358'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.576361656188965}
# {'_id': 144,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cybershot h200 black 20 1mp 26x new 027242862241 | ebay',
#  'matches': ['www.ebay.com//48441'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.578879594802856}
# {'_id': 145,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//52878'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.581705331802368}
# {'_id': 146,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//53432'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.584231853485107}
# {'_id': 147,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1mp digital camera 26x optical '
#                 'zoom | ebay',
#  'matches': ['www.ebay.com//55013'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.587238788604736}
# {'_id': 148,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//55273'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.589738368988037}
# {'_id': 149,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cybershot dsc h200 20 1 mp 26x digital camera w 3" lcd '
#                 'optical steadyshot 027242862241 | ebay',
#  'matches': ['www.ebay.com//56954'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.592182874679565}
# {'_id': 150,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//59551'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.59471583366394}
# {'_id': 151,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1mp digital camera 26x optical '
#                 'zoom | ebay',
#  'matches': ['www.ebay.com//59600'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.597683906555176}
# {'_id': 152,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//60261'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.601367712020874}
# {'_id': 153,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc h200 20 1 mp digital camera black '
#                 '027242862241 | ebay',
#  'matches': ['www.ebay.com//60366'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.604525566101074}
# {'_id': 154,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber-shot dsc-h200 20.1 mp digital camera - black',
#  'matches': ['www.ebay.com//60385'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.607312440872192}
# {'_id': 155,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc rx100m3 20 1mp digital black iii camera '
#                 'zeiss sonnar lens | ebay',
#  'matches': ['www.ebay.com//48099'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.609817266464233}
# {'_id': 156,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc rx100m3 b 20 1mp compact camera black | '
#                 'ebay',
#  'matches': ['www.ebay.com//48202'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.612401485443115}
# {'_id': 157,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony dsc rx100m3 20 1 megapixel digital camera black | ebay',
#  'matches': ['www.ebay.com//53917'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.615062236785889}
# {'_id': 158,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc rx100m3 rx100 iii 20 1mp camera with '
#                 'leather case lcj rxc | ebay',
#  'matches': ['www.ebay.com//55311'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.618895769119263}
# {'_id': 159,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony cyber shot dsc rx100m3 b 20 1mp compact camera black | '
#                 'ebay',
#  'matches': ['www.ebay.com//56912'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.62159013748169}
# {'_id': 160,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony dsc rx100m3 20 1 megapixel digital camera black | ebay',
#  'matches': ['www.ebay.com//58237'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.624285459518433}
# {'_id': 161,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony dsc-rx100m3 20.1mp wide angle 2.9x 1" cmos dscrx100m3',
#  'matches': ['www.henrys.com//2'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.626721620559692}
# {'_id': 162,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'new sony alpha a5000 mirrorless camera 20 1 megapixels black '
#                 '16 55mm zoom lens | ebay',
#  'matches': ['buy.net//6051',
#              'www.gosale.com//569',
#              'www.ebay.com//59773',
#              'www.gosale.com//630',
#              'www.ebay.com//54983'],
#  'mp': np.float64(20.1),
#  'price': np.float64(413.99),
#  'time': 9.629399061203003}
# {'_id': 163,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony alpha a5000 white digital camera kit w/ 16-50 mm lens '
#                 '(20.1 mp, sd/sdhc/sdxc/ms pro duo/ms pro-hg duo card slot) '
#                 'price comparison at buy.net',
#  'matches': ['buy.net//6408'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.63237977027893}
# {'_id': 164,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony î\x91 alpha a5000 20 1 mp digital slr camera canon focal '
#                 'reducer ii turbo | ebay',
#  'matches': ['www.ebay.com//43846'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.635783672332764}
# {'_id': 165,
#  'brand': 'sony',
#  'comparisons': 2970,
#  'description': 'sony a5000 20 1 mp wi fi digital camera silver w 16 50mm lens '
#                 'excellent cond | ebay',
#  'matches': ['www.ebay.com//45766'],
#  'mp': np.float64(20.1),
#  'price': np.float64(nan),
#  'time': 9.638933181762695}
# {'_id': 166,
#  'brand': 'sony',
#  'comparisons': 2970,
# ...
#                 'repair | ebay',
#  'matches': ['www.ebay.com//44600'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.794148921966553}
# {'_id': 506,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'dsc s750 sony cyber shot 7 2 mp digital camera battery '
#                 'charger 1 gb memory case | ebay',
#  'matches': ['www.ebay.com//46837'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.796781063079834}
# {'_id': 507,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony dsc s750 7 2 mp 3x zoom camera 2 gigabyte sandisk memory '
#                 'stick pro duo | ebay',
#  'matches': ['www.ebay.com//55809'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.800243616104126}
# {'_id': 508,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc s750 7 2 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//55857'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.803243160247803}
# {'_id': 509,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera pink | ebay',
#  'matches': ['www.ebay.com//43518'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.806569337844849}
# {'_id': 510,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'silver sony cyber shot dsc w120 camera 7 2 mp camera battery '
#                 'box only | ebay',
#  'matches': ['www.ebay.com//44743'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.809509038925171}
# {'_id': 511,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera blue with '
#                 'accesories | ebay',
#  'matches': ['www.ebay.com//45454'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.813137769699097}
# {'_id': 512,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//47254'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.816030263900757}
# {'_id': 513,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera black parts or '
#                 'not working | ebay',
#  'matches': ['www.ebay.com//53454'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.818727731704712}
# {'_id': 514,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera black | ebay',
#  'matches': ['www.ebay.com//54024'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.82132625579834}
# {'_id': 515,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//56139'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.82415771484375}
# {'_id': 516,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w120 7 2 mp digital camera pink with '
#                 'accesories | ebay',
#  'matches': ['www.ebay.com//58688'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.826740264892578}
# {'_id': 517,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera pink | ebay',
#  'matches': ['www.ebay.com//43120'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.829223871231079}
# {'_id': 518,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera pink sold as is '
#                 '| ebay',
#  'matches': ['www.ebay.com//47207'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.831797361373901}
# {'_id': 519,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera pink sold as is '
#                 '| ebay',
#  'matches': ['www.ebay.com//53409'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.834921598434448}
# {'_id': 520,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//54440'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.837889909744263}
# {'_id': 521,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera silver '
#                 '0027242705135 | ebay',
#  'matches': ['www.ebay.com//57823'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.840737581253052}
# {'_id': 522,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera w 3x optical '
#                 'zoom pink | ebay',
#  'matches': ['www.ebay.com//59768'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.843386888504028}
# {'_id': 523,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber shot dsc w55 7 2 mp digital camera pink sold as is '
#                 '| ebay',
#  'matches': ['www.ebay.com//60598'],
#  'mp': np.float64(7.2),
#  'price': np.float64(nan),
#  'time': 14.845787763595581}
# {'_id': 524,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cyber-shot dsc-s730 7.2 mp digital camera - silver',
#  'matches': ['www.ebay.com//59954', 'www.gosale.com//906'],
#  'mp': np.float64(7.2),
#  'price': np.float64(241.36),
#  'time': 14.848370552062988}
# {'_id': 525,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony cybershot dscw120 7.2mp digital on sale for $499.00',
#  'matches': ['www.ebay.com//24846',
#              'www.gosale.com//1052',
#              'www.gosale.com//511',
#              'www.gosale.com//740',
#              'www.gosale.com//864'],
#  'mp': np.float64(7.2),
#  'price': np.float64(137.99),
#  'time': 14.850805282592773}
# {'_id': 526,
#  'brand': 'sony',
#  'comparisons': 4531,
#  'description': 'sony nex 5rk 6 1 mp digital camera w 18 55mm lens | ebay',
#  'matches': ['www.ebay.com//60156'],
#  'mp': np.float64(6.1),
#  'price': np.float64(nan),
#  'time': 14.853886604309082}
# {'_id': 527,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cybershot 6 0 megapixels dsc w30 3x optical zoom | ebay',
#  'matches': ['www.ebay.com//24945'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.940070152282715}
# {'_id': 528,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cybershot dscw50 6mp digital camera on sale for $405.48',
#  'matches': ['www.gosale.com//1472'],
#  'mp': np.float64(6.0),
#  'price': np.float64(241.49),
#  'time': 14.942412614822388}
# {'_id': 529,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cybershot dscw30 6mp digital camera on sale for $349.95',
#  'matches': ['www.gosale.com//455'],
#  'mp': np.float64(6.0),
#  'price': np.float64(227.69),
#  'time': 14.944903373718262}
# {'_id': 530,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cybershot dsc h2 6mp digital camera 12x zoom fully '
#                 'working missing button | ebay',
#  'matches': ['www.gosale.com//991',
#              'www.ebay.com//45202',
#              'www.ebay.com//60255'],
#  'mp': np.float64(6.0),
#  'price': np.float64(344.99),
#  'time': 14.947538375854492}
# {'_id': 531,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc h2 6 0 mp digital camera silver missing '
#                 'button | ebay',
#  'matches': ['www.ebay.com//45997'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.950191497802734}
# {'_id': 532,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc h2 6 0mp 12x optical zoom digital camera '
#                 'silver | ebay',
#  'matches': ['www.ebay.com//58457'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.95275354385376}
# {'_id': 533,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc s600 6 0 mp digital camera silver '
#                 '0027242678187 | ebay',
#  'matches': ['www.ebay.com//57320', 'www.gosale.com//1072'],
#  'mp': np.float64(6.0),
#  'price': np.float64(141.44),
#  'time': 14.955516576766968}
# {'_id': 534,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc w50 6 0 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//44247'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.957998752593994}
# {'_id': 535,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc w50 6 0 mp digital camera with '
#                 'accessories silver | ebay',
#  'matches': ['www.ebay.com//45488'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.96030068397522}
# {'_id': 536,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc w50 6 0 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//46351'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.963141202926636}
# {'_id': 537,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc w50 6 0 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//47413'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.965574741363525}
# {'_id': 538,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'broken sony cyber shot dsc w50 6 0 mp digital camera silver | '
#                 'ebay',
#  'matches': ['www.ebay.com//55469'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.968741178512573}
# {'_id': 539,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cyber shot dsc w50 6 0 mp digital camera | ebay',
#  'matches': ['www.ebay.com//56061'],
#  'mp': np.float64(6.0),
#  'price': np.float64(nan),
#  'time': 14.971629858016968}
# {'_id': 540,
#  'brand': 'sony',
#  'comparisons': 4563,
#  'description': 'sony cybershot dsc-m2 5.1mp digital on sale for $505.98',
#  'matches': ['www.gosale.com//1004'],
#  'mp': np.float64(5.1),
#  'price': np.float64(379.49),
#  'time': 14.974252700805664}
# {'_id': 541,
#  'brand': 'sony',
#  'comparisons': 4570,
#  'description': 'sony cybershot dsch1 5.1mp digital camera on sale for $261.48',
#  'matches': ['www.gosale.com//1406'],
#  'mp': np.float64(5.1),
#  'price': np.float64(379.49),
#  'time': 14.996548652648926}
# {'_id': 542,
#  'brand': 'sony',
#  'comparisons': 4570,
#  'description': 'sony dsc h1 cyber shot 5 1 mega pixels 12 0x zoom tamrac '
#                 'digital case | ebay',
#  'matches': ['www.ebay.com//45638'],
#  'mp': np.float64(5.1),
#  'price': np.float64(nan),
#  'time': 14.99993109703064}
# {'_id': 543,
#  'brand': 'sony',
#  'comparisons': 4570,
#  'description': 'sony cyber shot dsc h1 12x zoom super steady shot 5 1 mega '
#                 'pixel digital camera | ebay',
#  'matches': ['www.ebay.com//59211'],
#  'mp': np.float64(5.1),
#  'price': np.float64(nan),
#  'time': 15.003377199172974}
# {'_id': 544,
#  'brand': 'sony',
#  'comparisons': 4570,
#  'description': 'sony cybershot dsc h1 5 0 mp digital camera excellent and '
#                 'working tested | ebay',
#  'matches': ['www.ebay.com//41958'],
#  'mp': np.float64(5.0),
#  'price': np.float64(nan),
#  'time': 15.007535457611084}
# {'_id': 545,
#  'brand': 'sony',
#  'comparisons': 4573,
#  'description': 'sony cyber shot dsc s40 4 1 mp digital camera silver | ebay',
#  'matches': ['www.ebay.com//23926'],
#  'mp': np.float64(4.1),
#  'price': np.float64(nan),
#  'time': 15.019620180130005}
# {'_id': 546,
#  'brand': 'sony',
#  'comparisons': 4573,
#  'description': 'sony cybershot dscs40 4.1 mp digital on sale for $95.48',
#  'matches': ['www.gosale.com//517'],
#  'mp': np.float64(4.1),
#  'price': np.float64(206.97),
#  'time': 15.022446393966675}
# {'_id': 547,
#  'brand': 'sony',
#  'comparisons': 4585,
#  'description': 'sony mvccd350 cd mavica 3.2mp digital on sale for $355.49',
#  'matches': ['www.gosale.com//556'],
#  'mp': np.float64(3.2),
#  'price': np.float64(793.49),
#  'time': 15.062723159790039}
# {'_id': 548,
#  'brand': 'sony',
#  'comparisons': 4585,
#  'description': 'sony mavica mvc cd350 3 2 mp digital camera black silver '
#                 '0027242624221 | ebay',
#  'matches': ['www.ebay.com//44191'],
#  'mp': np.float64(3.2),
#  'price': np.float64(nan),
#  'time': 15.066143035888672}
# {'_id': 549,
#  'brand': 'sony',
#  'comparisons': 4585,
#  'description': 'sony mavica mvc cd350 3 2 mp digital camera black silver '
#                 '0027242624221 | ebay',
#  'matches': ['www.ebay.com//45422'],
#  'mp': np.float64(3.2),
#  'price': np.float64(nan),
#  'time': 15.068795919418335}
# {'_id': 550,
#  'brand': 'sony',
#  'comparisons': 4585,
#  'description': 'sony mavica mvc cd350 3 2 mp digital camera black silver '
#                 '0027242624221 | ebay',
#  'matches': ['www.ebay.com//54784'],
#  'mp': np.float64(3.2),
#  'price': np.float64(nan),
#  'time': 15.07258677482605}
# {'_id': 551,
#  'brand': 'sony',
#  'comparisons': 4585,
#  'description': 'sony mavica mvc cd350 3 2 mp digital camera black silver '
#                 '0027242624221 | ebay',
#  'matches': ['www.ebay.com//56721'],
#  'mp': np.float64(3.2),
#  'price': np.float64(nan),
#  'time': 15.075418472290039}
# {'_id': 552,
#  'brand': 'sony',
#  'comparisons': 4585,
#  'description': 'sony cd mavica smart zoom mvc cd350 digital 3 2mp camera '
#                 '0027242624221 | ebay',
#  'matches': ['www.ebay.com//58956'],
#  'mp': np.float64(3.2),
#  'price': np.float64(nan),
#  'time': 15.078661918640137}
# {'_id': 553,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mvcfd200 fd mavica 2mp digital still on sale for $299.99',
#  'matches': ['www.gosale.com//465'],
#  'mp': np.float64(2.0),
#  'price': np.float64(793.49),
#  'time': 15.15415072441101}
# {'_id': 554,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mavica mvc fd200 2 0mp digital dual media still camera '
#                 'untested | ebay',
#  'matches': ['www.ebay.com//42653'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.15682077407837}
# {'_id': 555,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony fd mavica mvc fd200 digital camera 2 0 megapixels w case '
#                 'booklet more | ebay',
#  'matches': ['www.ebay.com//44850'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.159284114837646}
# {'_id': 556,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'used genuine sony fd mavica mvc fd200 digital still camera '
#                 '9110064 2mp | ebay',
#  'matches': ['www.ebay.com//53318'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.16181755065918}
# {'_id': 557,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mavica digital camera mvc fd200 2 0 mp black metallic '
#                 'silver w accessor | ebay',
#  'matches': ['www.ebay.com//56981'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.164745330810547}
# {'_id': 558,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mavica mvc fd200 2 0 mp digital camera black metallic '
#                 'silver | ebay',
#  'matches': ['www.ebay.com//58189'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.16736388206482}
# {'_id': 559,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mavica mvc fd200 2 0 mp digital camera black metallic '
#                 'silver | ebay',
#  'matches': ['www.ebay.com//59590'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.170015573501587}
# {'_id': 560,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mvc fd200 mavica 2 megapixels digital camera 3404011 | '
#                 'ebay',
#  'matches': ['www.ebay.com//59871'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.172419786453247}
# {'_id': 561,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'sony mvc fd200 mavica 2 megapixels digital camera 3404011 3 '
#                 '5" floppy disc | ebay',
#  'matches': ['www.ebay.com//60827'],
#  'mp': np.float64(2.0),
#  'price': np.float64(nan),
#  'time': 15.17507028579712}
# {'_id': 562,
#  'brand': 'sony',
#  'comparisons': 4614,
#  'description': 'enxun new unique case 1.3mp sensor720p 1/2.8 sony cmos '
#                 '1200tvl cctv camera - buy 1200tvl cctv camera product on '
#                 'alibaba.com',
#  'matches': ['www.alibaba.com//36979'],
#  'mp': np.float64(1.3),
#  'price': np.float64(59.8),
#  'time': 15.178349733352661}
# BrewER completed successfully! Emitted 563 entities.

# %%
print(results_df.columns.tolist())
print(results_df[["matches", "_id", "mp"]].head())
# Out:
# ['_id', 'description', 'brand', 'price', 'mp', 'matches', 'comparisons', 'time']
#                                              matches  _id    mp
# 0              [www.gosale.com//1215, buy.net//5881]    0  36.4
# 1                              [www.ebay.com//53668]    1  36.4
# 2                              [www.ebay.com//46949]    2  24.3
# 3  [www.ebay.com//59882, www.gosale.com//531, www...    3  24.3
# 4                              [www.ebay.com//42367]    4  24.3

# %%
# Create evaluation dataframe
brewer_dataframe = pd.DataFrame(brewer_results)

if len(brewer_dataframe) > 0:
    brewer_dataframe["running_tp"] = brewer_dataframe["tp"].cumsum()
    brewer_dataframe["running_fp"] = brewer_dataframe["fp"].cumsum()
    brewer_dataframe["running_fn"] = len(batch_filtered_pairs) - brewer_dataframe["running_tp"]
    brewer_dataframe["running_correct"] = brewer_dataframe["correct"].cumsum()

    brewer_dataframe["recall"] = (brewer_dataframe["running_tp"] / (brewer_dataframe["running_tp"] + brewer_dataframe["running_fn"])).replace(np.nan, 0)
    brewer_dataframe["precision"] = (brewer_dataframe["running_tp"] / (brewer_dataframe["running_tp"] + brewer_dataframe["running_fp"])).replace(np.nan, 0)

    brewer_dataframe["accuracy"] = brewer_dataframe["running_correct"] / len(brewer_dataframe)

    brewer_dataframe["f1"] = (
        2
        * (brewer_dataframe["precision"] * brewer_dataframe["recall"])
        / (brewer_dataframe["precision"] + brewer_dataframe["recall"])
    )

    brewer_dataframe.to_csv("output/brewer_results.csv", index=False)
else:
    print("No results from BrewER to evaluate.")

# %%
brewer_dataframe
# Out:
#      elapsed_time  comparisons  correct  tp  fp  running_tp  running_fp  \
# 0        1.285996            2     True   1   0           1           0
# 1        1.289723            2    False   0   0           1           0
# 2        2.392334          412     True   0   0           1           0
# 3        2.395238          412     True  10   0          11           0
# 4        2.397887          412     True   0   0          11           0
# ..            ...          ...      ...  ..  ..         ...         ...
# 558     15.167364         4614    False   0   0         241           0
# 559     15.170016         4614    False   0   0         241           0
# 560     15.172420         4614    False   0   0         241           0
# 561     15.175070         4614    False   0   0         241           0
# 562     15.178350         4614    False   0   0         241           0
#
#      running_fn  running_correct    recall  precision  accuracy        f1
# 0          3507                1  0.000285        1.0  0.001776  0.000570
# 1          3507                1  0.000285        1.0  0.001776  0.000570
# 2          3507                2  0.000285        1.0  0.003552  0.000570
# 3          3497                3  0.003136        1.0  0.005329  0.006252
# 4          3497                4  0.003136        1.0  0.007105  0.006252
# ..          ...              ...       ...        ...       ...       ...
# 558        3267               10  0.068700        1.0  0.017762  0.128568
# 559        3267               10  0.068700        1.0  0.017762  0.128568
# 560        3267               10  0.068700        1.0  0.017762  0.128568
# 561        3267               10  0.068700        1.0  0.017762  0.128568
# 562        3267               10  0.068700        1.0  0.017762  0.128568
#
# [563 rows x 13 columns]

# %%
# Display BrewER results
print("\n=== BrewER RESULTS ===")

if len(brewer_dataframe) > 0:
    print("BrewER Performance Metrics:")
    print(brewer_dataframe)
    print(f"\nFinal Metrics:")
    print(f"- Final Precision: {brewer_dataframe['precision'].iloc[-1]:.4f}")
    print(f"- Final Recall: {brewer_dataframe['recall'].iloc[-1]:.4f}")
    print(f"- Final Accuracy: {brewer_dataframe['accuracy'].iloc[-1]:.4f}")
else:
    print("No performance metrics available from BrewER.")

if 'results_df' in locals() and len(results_df) > 0:
    print(f"\nBrewER entities emitted ({len(results_df)}):")
    print(results_df.head(10))
    results_df.to_csv("output/brewer_entities.csv", index=False)
else:
    print("No entities were emitted by BrewER.")
# Out:
# === BrewER RESULTS ===
# BrewER Performance Metrics:
#      elapsed_time  comparisons  correct  tp  fp  running_tp  running_fp  \
# 0        1.285996            2     True   1   0           1           0
# 1        1.289723            2    False   0   0           1           0
# 2        2.392334          412     True   0   0           1           0
# 3        2.395238          412     True  10   0          11           0
# 4        2.397887          412     True   0   0          11           0
# ..            ...          ...      ...  ..  ..         ...         ...
# 558     15.167364         4614    False   0   0         241           0
# 559     15.170016         4614    False   0   0         241           0
# 560     15.172420         4614    False   0   0         241           0
# 561     15.175070         4614    False   0   0         241           0
# 562     15.178350         4614    False   0   0         241           0
#
#      running_fn  running_correct    recall  precision  accuracy        f1
# 0          3507                1  0.000285        1.0  0.001776  0.000570
# 1          3507                1  0.000285        1.0  0.001776  0.000570
# 2          3507                2  0.000285        1.0  0.003552  0.000570
# 3          3497                3  0.003136        1.0  0.005329  0.006252
# 4          3497                4  0.003136        1.0  0.007105  0.006252
# ..          ...              ...       ...        ...       ...       ...
# 558        3267               10  0.068700        1.0  0.017762  0.128568
# 559        3267               10  0.068700        1.0  0.017762  0.128568
# 560        3267               10  0.068700        1.0  0.017762  0.128568
# 561        3267               10  0.068700        1.0  0.017762  0.128568
# 562        3267               10  0.068700        1.0  0.017762  0.128568
#
# [563 rows x 13 columns]
#
# Final Metrics:
# - Final Precision: 1.0000
# - Final Recall: 0.0687
# - Final Accuracy: 0.0178
#
# BrewER entities emitted (563):
#    _id                                        description brand    price  \
# 0    0  sony a7r black interchangeable lens digital sl...  sony  1586.99
# 1    1  sony alpha a7r 36 4 mp full frame mirrorless c...  sony      NaN
# 2    2  sony alpha ilce 6000l 24 3mp slr digital camer...  sony      NaN
# 3    3  sony a alpha nex 7 24 3 mp digital camera w 18...  sony   827.99
# 4    4  sony î alpha nex 7 24 3 mp digital camera sel...  sony      NaN
# 5    5  sony alpha nex 7 24 3mp digital camera with 18...  sony      NaN
# 6    6  sony nex 7 digital camera 24 3 mp w 50 mm 1 8f...  sony      NaN
# 7    7  sony a alpha nex 7 24 3 mp digital camera blac...  sony      NaN
# 8    8  sony nex 7 24 3 mp digital camera black kit w ...  sony      NaN
# 9    9  sony alpha nex 7 digital slr camera w 18 55mm ...  sony      NaN
#
#      mp                                            matches  comparisons  \
# 0  36.4              [www.gosale.com//1215, buy.net//5881]            2
# 1  36.4                              [www.ebay.com//53668]            2
# 2  24.3                              [www.ebay.com//46949]          412
# 3  24.3  [www.ebay.com//59882, www.gosale.com//531, www...          412
# 4  24.3                              [www.ebay.com//42367]          412
# 5  24.3                              [www.ebay.com//42416]          412
# 6  24.3                              [www.ebay.com//44911]          412
# 7  24.3                              [www.ebay.com//48530]          412
# 8  24.3                              [www.ebay.com//53798]          412
# 9  24.3                              [www.ebay.com//54864]          412
#
#        time
# 0  1.285996
# 1  1.289723
# 2  2.392334
# 3  2.395238
# 4  2.397887
# 5  2.400558
# 6  2.403246
# 7  2.406068
# 8  2.408704
# 9  2.411480

# %%
# Comparison summary
print("\n" + "="*50)
print("COMPARISON SUMMARY: Batch vs BrewER")
print("="*50)

print(f"\nBatch Processing (Baseline):")
print(f"  - Comparisons: {batch_comparisons:,}")
print(f"  - Elapsed time: {batch_elapsed_time:.4f}s")
print(f"  - Entities emitted: {len(batch_filtered)}")

if len(brewer_dataframe) > 0:
    total_brewer_comparisons = brewer_dataframe["comparisons"].iloc[-1] if "comparisons" in brewer_dataframe.columns else 0
    total_brewer_time = brewer_dataframe["elapsed_time"].max() if "elapsed_time" in brewer_dataframe.columns else 0
    print(f"\nBrewER Processing (On-Demand):")
    print(f"  - Comparisons: {total_brewer_comparisons:,}")
    print(f"  - Elapsed time: {total_brewer_time:.4f}s")
    print(f"  - Entities emitted: {len(brewer_dataframe)}")
    
    if total_brewer_comparisons > 0 and batch_comparisons > 0:
        comp_reduction = ((batch_comparisons - total_brewer_comparisons) / batch_comparisons * 100)
        time_reduction = ((batch_elapsed_time - total_brewer_time) / batch_elapsed_time * 100)
        print(f"\nEfficiency Gains:")
        print(f"  - Comparison reduction: {comp_reduction:.2f}%")
        print(f"  - Time reduction: {time_reduction:.2f}%")
        print(f"  - Speedup factor: {batch_elapsed_time/total_brewer_time:.2f}x" if total_brewer_time > 0 else "")
else:
    print(f"\nBrewER Processing: No results to compare")

print("\n" + "="*50)
print("Query Configuration (same as BlendER experiments):")
print("  - SELECT: VOTE(_id), VOTE(description), VOTE(brand), MIN(price), AVG(mp)")
print("  - WHERE: brand = 'sony'")
print("  - ORDER BY: mp DESC")
print("  - LIMIT: TOP 10")
print("="*50)
# Out:
# ==================================================
# COMPARISON SUMMARY: Batch vs BrewER
# ==================================================
#
# Batch Processing (Baseline):
#   - Comparisons: 22,073
#   - Elapsed time: 59.1467s
#   - Entities emitted: 206
#
# BrewER Processing (On-Demand):
#   - Comparisons: 4,614
#   - Elapsed time: 15.1783s
#   - Entities emitted: 563
#
# Efficiency Gains:
#   - Comparison reduction: 79.10%
#   - Time reduction: 74.34%
#   - Speedup factor: 3.90x
#
# ==================================================
# Query Configuration (same as BlendER experiments):
#   - SELECT: VOTE(_id), VOTE(description), VOTE(brand), MIN(price), AVG(mp)
#   - WHERE: brand = 'sony'
#   - ORDER BY: mp DESC
#   - LIMIT: TOP 10
# ==================================================

# %%
# Side-by-side comparison of results
print("\n" + "="*80)
print("SIDE-BY-SIDE RESULTS COMPARISON")
print("="*80)

print("\nBatch Processing Results (sorted by mp DESC):")
if len(batch_filtered) > 0:
    display_cols = ['_id', 'brand', 'mp', 'price'] if 'price' in batch_filtered.columns else ['_id', 'brand', 'mp']
    print(batch_filtered[display_cols].head(10).to_string(index=False))
else:
    print("No batch results to display")

print(f"\nBrewER On-Demand Results:")
if 'results_df' in locals() and len(results_df) > 0:

    available_cols = [col for col in ['_id', 'brand', 'mp', 'price', 'comparisons', 'time'] if col in results_df.columns]
    print(results_df[available_cols].head(10).to_string(index=False))
else:
    print("No BrewER results to display")

print("\n" + "="*80)
# Out:
# ================================================================================
# SIDE-BY-SIDE RESULTS COMPARISON
# ================================================================================
#
# Batch Processing Results (sorted by mp DESC):
#                 _id brand   mp   price
#       buy.net//5881  sony 36.4 1586.99
#       buy.net//4330  sony 24.3     NaN
#       buy.net//6531  sony 24.3 1172.99
# www.ebay.com//43490  sony 24.3     NaN
# www.ebay.com//42034  sony 24.3  827.99
#   cammarkt.com//229  sony 24.3     NaN
# www.ebay.com//42742  sony 24.3 1655.97
# www.gosale.com//540  sony 24.3 1379.99
# www.ebay.com//54853  sony 24.3     NaN
# www.ebay.com//46677  sony 24.3     NaN
#
# BrewER On-Demand Results:
#  _id brand   mp   price  comparisons     time
#    0  sony 36.4 1586.99            2 1.285996
#    1  sony 36.4     NaN            2 1.289723
#    2  sony 24.3     NaN          412 2.392334
#    3  sony 24.3  827.99          412 2.395238
#    4  sony 24.3     NaN          412 2.397887
#    5  sony 24.3     NaN          412 2.400558
#    6  sony 24.3     NaN          412 2.403246
#    7  sony 24.3     NaN          412 2.406068
#    8  sony 24.3     NaN          412 2.408704
#    9  sony 24.3     NaN          412 2.411480
#
# ================================================================================

# %%
from itertools import combinations

def pairs_of(ids):
    return {tuple(sorted(p)) for p in combinations(ids, 2)}

pred_pairs = set()
if "matches" in results_df.columns:
    for m in results_df["matches"]:
        pred_pairs |= pairs_of(m)

print("pares preditos:", len(pred_pairs))
print("pares baseline:", len(batch_filtered_pairs))
print("TP:", len(pred_pairs & batch_filtered_pairs))
print("FP:", len(pred_pairs - batch_filtered_pairs))  # idealmente 0
print("FN:", len(batch_filtered_pairs - pred_pairs))  # se >0, é blocking/HAVING
# Out:
# pares preditos: 241
# pares baseline: 3508
# TP: 241
# FP: 0
# FN: 3267
